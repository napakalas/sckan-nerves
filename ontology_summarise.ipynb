# %% [markdown]
# ## Demo OntologyTracer
# to trace the connction of term_id to other terms

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ontology_tracer import OntologyTracer
from utility import GENERATED_DIR

# %%
onto_relation = OntologyTracer(GENERATED_DIR / 'UBERON_FMA_STRUCTURE.json')
# onto_relation.load_source()

# %%
onto_relation.trace_nerve_up('UBERON:0001759')
# Out:
# {'UBERON:0001785': {'distance': 1},
#  'UBERON:0011779': {'distance': 2},
#  'FMA:5865': {'distance': 1}}

# %%
onto_relation.trace_nerve_down('UBERON:0001759')
# Out:
# {'UBERON:3010740': {'distance': 1},
#  'UBERON:3010750': {'distance': 1},
#  'UBERON:0009673': {'distance': 1},
#  'UBERON:3010751': {'distance': 2},
#  'UBERON:3010764': {'distance': 2},
#  'FMA:6228': {'distance': 1},
#  'FMA:6220': {'distance': 1},
#  'FMA:6219': {'distance': 1},
#  'FMA:78582': {'distance': 2},
#  'FMA:65514': {'distance': 2},
#  'FMA:53612': {'distance': 2},
#  'FMA:6233': {'distance': 2},
#  'FMA:77213': {'distance': 2},
#  'FMA:54236': {'distance': 2},
#  'FMA:6670': {'distance': 2},
#  'FMA:0327083': {'distance': 2},
#  'FMA:268949': {'distance': 2},
#  'FMA:12131': {'distance': 2},
#  'FMA:6231': {'distance': 2},
#  'FMA:272320': {'distance': 2},
#  'FMA:0327366': {'distance': 2},
#  'FMA:6246': {'distance': 2},
#  'FMA:6232': {'distance': 2},
#  'FMA:6239': {'distance': 2},
#  'FMA:6234': {'distance': 2},
#  'FMA:65515': {'distance': 2},
#  'FMA:12132': {'distance': 2},
#  'FMA:272326': {'distance': 2},
#  'FMA:6247': {'distance': 2},
# ...

# %%
onto_relation.trace_nerve_up('UBERON:0001759')
# Out:
# {'UBERON:0001785': {'distance': 1},
#  'UBERON:0011779': {'distance': 2},
#  'FMA:5865': {'distance': 1}}

# %%
onto_relation.trace_subclasses('UBERON:0001759')
# Out:
# {'UBERON:3010740': {'distance': 1},
#  'UBERON:3010750': {'distance': 1},
#  'UBERON:0009673': {'distance': 1},
#  'UBERON:3010754': {'distance': 1},
#  'UBERON:0003535': {'distance': 1},
#  'UBERON:3010751': {'distance': 2},
#  'UBERON:3010764': {'distance': 2},
#  'UBERON:0035021': {'distance': 2},
#  'UBERON:0035020': {'distance': 2},
#  'FMA:6221': {'distance': 1},
#  'FMA:6228': {'distance': 1},
#  'FMA:6225': {'distance': 1},
#  'FMA:6220': {'distance': 1},
#  'FMA:6219': {'distance': 1},
#  'FMA:6213': {'distance': 1},
#  'FMA:18151': {'distance': 2},
#  'FMA:18157': {'distance': 2},
#  'FMA:6223': {'distance': 2},
#  'FMA:6224': {'distance': 2},
#  'FMA:6222': {'distance': 2},
#  'FMA:18172': {'distance': 3},
#  'FMA:18174': {'distance': 3},
#  'FMA:18178': {'distance': 3},
#  'FMA:18177': {'distance': 3},
#  'FMA:6230': {'distance': 3},
#  'FMA:18175': {'distance': 3},
#  'FMA:6229': {'distance': 3},
#  'FMA:18176': {'distance': 3},
#  'FMA:53555': {'distance': 4},
# ...

# %%
onto_relation.trace_branch_down('UBERON:0001759')
# Out:
# {'UBERON:0003716': {'distance': 1},
#  'UBERON:0011326': {'distance': 1},
#  'UBERON:0002009': {'distance': 1},
#  'UBERON:0000929': {'distance': 1},
#  'FMA:6232': {'distance': 1},
#  'FMA:6239': {'distance': 1},
#  'FMA:6226': {'distance': 1},
#  'FMA:6244': {'distance': 1},
#  'FMA:6234': {'distance': 1},
#  'FMA:6233': {'distance': 1},
#  'FMA:6231': {'distance': 1},
#  'FMA:6227': {'distance': 1},
#  'FMA:6245': {'distance': 1},
#  'FMA:6246': {'distance': 1},
#  'FMA:6237': {'distance': 1},
#  'FMA:6694': {'distance': 2},
#  'FMA:53593': {'distance': 2},
#  'FMA:6695': {'distance': 2},
#  'FMA:6692': {'distance': 2},
#  'FMA:6691': {'distance': 2},
#  'FMA:6243': {'distance': 2},
#  'FMA:6240': {'distance': 2},
#  'FMA:6706': {'distance': 3},
#  'FMA:6705': {'distance': 3},
#  'FMA:6708': {'distance': 3},
#  'FMA:6709': {'distance': 3},
#  'FMA:6707': {'distance': 3},
#  'FMA:6702': {'distance': 3},
#  'FMA:6700': {'distance': 3},
#  'FMA:53544': {'distance': 3},
# ...

# %%
onto_relation.trace_branch_up('UBERON:0001759')
# Out:
# {}

# %%
onto_relation.trace_part_down('UBERON:0001759')
# Out:
# {'UBERON:3010750': {'distance': 1},
#  'UBERON:0009673': {'distance': 1},
#  'UBERON:3010754': {'distance': 1},
#  'UBERON:0003535': {'distance': 1},
#  'UBERON:3010751': {'distance': 2},
#  'UBERON:3010764': {'distance': 2},
#  'FMA:6221': {'distance': 1},
#  'FMA:6225': {'distance': 1},
#  'FMA:6228': {'distance': 1},
#  'FMA:6213': {'distance': 1},
#  'FMA:6223': {'distance': 2},
#  'FMA:6224': {'distance': 2},
#  'FMA:6222': {'distance': 2},
#  'FMA:6230': {'distance': 3},
#  'FMA:6229': {'distance': 3}}

# %%
onto_relation.trace_part_up('UBERON:0001759')
# Out:
# {'UBERON:0001033': {'distance': 1},
#  'FMA:9903': {'distance': 1},
#  'FMA:7157': {'distance': 2},
#  'FMA:20394': {'distance': 3},
#  'FMA:67812': {'distance': 3},
#  'FMA:67811': {'distance': 3}}
